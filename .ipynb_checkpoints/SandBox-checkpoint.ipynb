# %%
audiopath = '/Users/antoine/Desktop/GPH/E2024/PFE/song&samples/gC.wav'
_80_bpm = "test/80bpm.wav"
import librosa
import matplotlib.pyplot as plt
import numpy as np
import scipy
from IPython.display import Audio

# %%
y, sr = librosa.load(audiopath)
Audio(y,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load(audiopath)
y = librosa.effects.harmonic(y)
times = librosa.times_like(y, sr=sr)

# %% [markdown]
# # find wich note is played when

# %%
iD_harmonic = y
iD_percussive = y = librosa.effects.percussive(y)

tempo, beat = librosa.beat.beat_track(y=iD_percussive, sr=sr)
iD_percussive
# Out:
# array([-1.5767648e-07, -1.6349469e-07, -1.8542042e-07, ...,
#        -4.4711491e-05, -3.9787941e-05, -3.7311416e-05], dtype=float32)

# %%
chroma_harm = librosa.feature.chroma_cqt(y=iD_harmonic, sr=sr,cqt_mode="hybrid", threshold=1.3, hop_length=1382,n_octaves=8,bins_per_octave=36)
chroma_filter = np.minimum(chroma_harm,librosa.decompose.nn_filter(chroma_harm,aggregate=np.median,metric='cosine'))
chroma_smooth = scipy.ndimage.median_filter(chroma_filter, size=(1, 9))

# %%
len(iD_harmonic)
Audio(iD_harmonic, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# dimension 1 -> note de C à B
# dimension 2 -> 
notes = ["C","C#","D","D#","E","F","F#","G","G#","A","A#","B"]

X = librosa.iirt(y=iD_harmonic, sr=sr, win_length=2048, hop_length=2048//2, center=True, tuning=0.0)
gamma = 1
X = np.log(1.0 + gamma * X)
X = librosa.cqt(y=X, bins_per_octave=12, n_bins=librosa.note_to_midi("E7") - librosa.note_to_midi("E2") + 1,fmin=librosa.midi_to_hz(24), norm=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       6 gamma = 1
#       7 X = np.log(1.0 + gamma * X)
# ----> 8 X = librosa.cqt(y=X, bins_per_octave=12, n_bins=midi_max-midi_min+1,fmin=librosa.midi_to_hz(24), norm=None)
#
# NameError: name 'midi_max' is not defined

# %%
fig, ax = plt.subplots(nrows=1)
lb.display.specshow(chroma_harm, y_axis='chroma', x_axis='time', ax=ax)
ax.set(ylabel="notes")
ax.label_outer()

# %% [markdown]
# # Use percussive part of the signal to extract the time rythm information

# %%
ratio = lb.feature.tempogram_ratio(y=iD_percussive, sr=sr, bpm=tempo.item())

# %%
import librosa
import numpy as np

# %%
tempo, beats = librosa.beat.beat_track(y=y, sr=sr, trim=False)
C = np.abs(librosa.cqt(y=y, sr=sr))
beats = librosa.util.fix_frames(beats)

# %%
C_avg = librosa.util.sync(C, beats)

# %%
C_med = librosa.util.sync(C, beats,
                             aggregate=np.median)

# %%
import matplotlib.pyplot as plt
beat_t = librosa.frames_to_time(beats, sr=sr)
fig, ax = plt.subplots(nrows=2, sharex=True, sharey=True)
ax[0].yaxis.set_major_formatter(librosa.display.ChromaFormatter())
librosa.display.specshow(librosa.amplitude_to_db(C,
                                                 ref=np.max),
                         x_axis='time', ax=ax[0])
ax[0].set(title='CQT power, shape={}'.format(C.shape))
ax[0].label_outer()
librosa.display.specshow(librosa.amplitude_to_db(C_med,
                                                 ref=np.max),
                         x_coords=beat_t, x_axis='time', ax=ax[1])
ax[1].set(title='Beat synchronous CQT power, '
                'shape={}'.format(C_med.shape))
ax[1].label_outer()
